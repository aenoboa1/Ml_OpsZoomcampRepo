# %%
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')

## visualization libraries

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse

# %%
df = pd.read_parquet('data/green_tripdata_2022-01.parquet')

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2022-01-01 00:14:21   2022-01-01 00:15:33                  N
# 1             1  2022-01-01 00:20:55   2022-01-01 00:29:38                  N
# 2             1  2022-01-01 00:57:02   2022-01-01 01:13:14                  N
# 3             2  2022-01-01 00:07:42   2022-01-01 00:15:57                  N
# 4             2  2022-01-01 00:07:50   2022-01-01 00:28:52                  N
# ...         ...                  ...                   ...                ...
# 62490         2  2022-01-31 23:25:00   2022-01-31 23:33:00               None
# 62491         2  2022-01-31 23:52:00   2022-02-01 00:10:00               None
# 62492         2  2022-01-31 23:17:00   2022-01-31 23:36:00               None
# 62493         2  2022-01-31 23:45:00   2022-01-31 23:55:00               None
# 62494         2  2022-01-31 23:52:00   2022-02-01 00:26:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            42            42              1.0           0.44
# 1             1.0           116            41              1.0           2.10
# 2             1.0            41           140              1.0           3.70
# 3             1.0           181           181              1.0           1.69
# 4             1.0            33           170              1.0           6.26
# ...           ...           ...           ...              ...            ...
# 62490         NaN            40            65              NaN           1.40
# 62491         NaN            36            61              NaN           2.97
# 62492         NaN            75           167              NaN           3.70
# 62493         NaN           116           166              NaN           1.88
# 62494         NaN           225           179              NaN           9.60
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0             3.50   0.50      0.5        0.00           0.0      None
# 1             9.50   0.50      0.5        0.00           0.0      None
# 2            14.50   3.25      0.5        4.60           0.0      None
# 3             8.00   0.50      0.5        0.00           0.0      None
# 4            22.00   0.50      0.5        5.21           0.0      None
# ...            ...    ...      ...         ...           ...       ...
# 62490         8.38   0.00      0.0        1.93           0.0      None
# 62491        14.92   0.00      0.0        0.00           0.0      None
# 62492        16.26   0.00      0.0        0.00           0.0      None
# 62493         9.48   0.00      0.0        2.17           0.0      None
# 62494        32.18   0.00      0.0        7.23          10.0      None
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          4.80           2.0        1.0
# 1                        0.3         10.80           2.0        1.0
# 2                        0.3         23.15           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                        0.3         31.26           1.0        1.0
# ...                      ...           ...           ...        ...
# 62490                    0.3         10.61           NaN        NaN
# 62491                    0.3         15.22           NaN        NaN
# 62492                    0.3         16.56           NaN        NaN
# 62493                    0.3         11.95           NaN        NaN
# 62494                    0.3         49.71           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      0.00
# 2                      2.75
# 3                      0.00
# 4                      2.75
# ...                     ...
# 62490                   NaN
# 62491                   NaN
# 62492                   NaN
# 62493                   NaN
# 62494                   NaN
#
# [62495 rows x 20 columns]

# %%
df[df.trip_type == 2]  # Filter by trip_type
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 17            2  2022-01-01 00:12:00   2022-01-01 00:26:26                  N
# 19            2  2022-01-01 00:54:40   2022-01-01 01:17:02                  N
# 24            2  2022-01-01 00:02:43   2022-01-01 00:18:31                  N
# 25            2  2022-01-01 00:45:23   2022-01-01 00:59:38                  N
# 29            2  2022-01-01 00:02:14   2022-01-01 00:02:16                  N
# ...         ...                  ...                   ...                ...
# 56165         2  2022-01-31 23:06:05   2022-01-31 23:15:19                  N
# 56166         2  2022-01-31 23:56:36   2022-02-01 00:08:29                  N
# 56183         2  2022-01-31 23:44:31   2022-01-31 23:45:20                  N
# 56189         2  2022-01-31 23:33:37   2022-01-31 23:33:50                  N
# 56198         2  2022-01-31 23:39:20   2022-01-31 23:52:25                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 17            5.0           213           174              1.0           5.57
# 19            5.0           185           119              1.0           6.60
# 24            5.0            66           234              4.0           3.96
# 25            5.0            33           233              4.0           6.20
# 29            5.0            42           264              1.0           0.00
# ...           ...           ...           ...              ...            ...
# 56165         5.0           185           208              1.0           3.88
# 56166         5.0           185           182              1.0           3.93
# 56183         5.0           210           210              1.0           0.08
# 56189         5.0           191           191              1.0           0.00
# 56198         5.0           119            20              1.0           3.66
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 17            20.0    0.0      0.0        0.00           0.0      None
# 19            25.0    0.0      0.0        0.00           0.0      None
# 24            25.0    0.0      0.0        5.61           0.0      None
# 25            60.0    0.0      0.0       12.61           0.0      None
# 29            10.0    0.0      0.0        0.00           0.0      None
# ...            ...    ...      ...         ...           ...       ...
# 56165         15.0    0.0      0.0        0.00           0.0      None
# 56166         12.0    0.0      0.0        0.00           0.0      None
# 56183          8.0    0.0      0.0        0.00           0.0      None
# 56189        195.0    0.0      0.0        0.00           0.0      None
# 56198         12.0    0.0      0.0        0.00           0.0      None
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 17                       0.3         20.30           2.0        2.0
# 19                       0.3         25.30           2.0        2.0
# 24                       0.3         33.66           1.0        2.0
# 25                       0.3         75.66           1.0        2.0
# 29                       0.3         10.30           1.0        2.0
# ...                      ...           ...           ...        ...
# 56165                    0.3         15.30           2.0        2.0
# 56166                    0.3         12.30           2.0        2.0
# 56183                    0.3          8.30           1.0        2.0
# 56189                    0.3        195.30           2.0        2.0
# 56198                    0.3         12.30           2.0        2.0
#
#        congestion_surcharge
# 17                     0.00
# 19                     0.00
# 24                     2.75
# 25                     2.75
# 29                     0.00
# ...                     ...
# 56165                  0.00
# 56166                  0.00
# 56183                  0.00
# 56189                  0.00
# 56198                  0.00
#
# [2300 rows x 20 columns]

# %%
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

# %%
df['duration']  = df.lpep_dropoff_datetime - df.lpep_pickup_datetime # obtain duration by sustracting two dates

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2022-01-01 00:14:21   2022-01-01 00:15:33                  N
# 1             1  2022-01-01 00:20:55   2022-01-01 00:29:38                  N
# 2             1  2022-01-01 00:57:02   2022-01-01 01:13:14                  N
# 3             2  2022-01-01 00:07:42   2022-01-01 00:15:57                  N
# 4             2  2022-01-01 00:07:50   2022-01-01 00:28:52                  N
# ...         ...                  ...                   ...                ...
# 62490         2  2022-01-31 23:25:00   2022-01-31 23:33:00               None
# 62491         2  2022-01-31 23:52:00   2022-02-01 00:10:00               None
# 62492         2  2022-01-31 23:17:00   2022-01-31 23:36:00               None
# 62493         2  2022-01-31 23:45:00   2022-01-31 23:55:00               None
# 62494         2  2022-01-31 23:52:00   2022-02-01 00:26:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            42            42              1.0           0.44
# 1             1.0           116            41              1.0           2.10
# 2             1.0            41           140              1.0           3.70
# 3             1.0           181           181              1.0           1.69
# 4             1.0            33           170              1.0           6.26
# ...           ...           ...           ...              ...            ...
# 62490         NaN            40            65              NaN           1.40
# 62491         NaN            36            61              NaN           2.97
# 62492         NaN            75           167              NaN           3.70
# 62493         NaN           116           166              NaN           1.88
# 62494         NaN           225           179              NaN           9.60
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             3.50  ...      0.5        0.00           0.0       None
# 1             9.50  ...      0.5        0.00           0.0       None
# 2            14.50  ...      0.5        4.60           0.0       None
# 3             8.00  ...      0.5        0.00           0.0       None
# 4            22.00  ...      0.5        5.21           0.0       None
# ...            ...  ...      ...         ...           ...        ...
# 62490         8.38  ...      0.0        1.93           0.0       None
# 62491        14.92  ...      0.0        0.00           0.0       None
# 62492        16.26  ...      0.0        0.00           0.0       None
# 62493         9.48  ...      0.0        2.17           0.0       None
# 62494        32.18  ...      0.0        7.23          10.0       None
#
#       improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                       0.3          4.80           2.0        1.0
# 1                       0.3         10.80           2.0        1.0
# 2                       0.3         23.15           1.0        1.0
# 3                       0.3          9.30           2.0        1.0
# 4                       0.3         31.26           1.0        1.0
# ...                     ...           ...           ...        ...
# 62490                   0.3         10.61           NaN        NaN
# 62491                   0.3         15.22           NaN        NaN
# 62492                   0.3         16.56           NaN        NaN
# 62493                   0.3         11.95           NaN        NaN
# 62494                   0.3         49.71           NaN        NaN
#
#        congestion_surcharge        duration
# 0                      0.00 0 days 00:01:12
# 1                      0.00 0 days 00:08:43
# 2                      2.75 0 days 00:16:12
# 3                      0.00 0 days 00:08:15
# 4                      2.75 0 days 00:21:02
# ...                     ...             ...
# 62490                   NaN 0 days 00:08:00
# 62491                   NaN 0 days 00:18:00
# 62492                   NaN 0 days 00:19:00
# 62493                   NaN 0 days 00:10:00
# 62494                   NaN 0 days 00:34:00
#
# [62495 rows x 21 columns]

# %%
df.duration = df.duration.apply(lambda td: td.total_seconds()/60 ) # apply to every row with lambd

# %%
df.duration
# Out:
# 0         1.200000
# 1         8.716667
# 2        16.200000
# 3         8.250000
# 4        21.033333
#            ...
# 62490     8.000000
# 62491    18.000000
# 62492    19.000000
# 62493    10.000000
# 62494    34.000000
# Name: duration, Length: 62495, dtype: float64

# %%
plt.style.use('fivethirtyeight')

# %%
sns.distplot(df.duration); # visualize distribution

# %% [markdown]
# Long Tailed Distribution

# %%
df.duration.describe(percentiles=[0.95,0.98,0.99])
# Out:
# count    62495.000000
# mean        19.019387
# std         78.215732
# min          0.000000
# 50%         11.583333
# 95%         35.438333
# 98%         49.722667
# 99%         68.453000
# max       1439.466667
# Name: duration, dtype: float64

# %%
((df.duration >= 1) & (df.duration <= 60)).mean()
# Out:
# 0.9537242979438355

# %%
categorical = ['PULocationID','DOLocationID']
numerical = ['trip_distance']

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
df[categorical] = df[categorical].astype(str)

# %%
df[categorical + numerical].iloc[:10].to_dict(orient="records")
# Out:
# [{'PULocationID': '42', 'DOLocationID': '42', 'trip_distance': 0.44},
#  {'PULocationID': '116', 'DOLocationID': '41', 'trip_distance': 2.1},
#  {'PULocationID': '41', 'DOLocationID': '140', 'trip_distance': 3.7},
#  {'PULocationID': '181', 'DOLocationID': '181', 'trip_distance': 1.69},
#  {'PULocationID': '33', 'DOLocationID': '170', 'trip_distance': 6.26},
#  {'PULocationID': '150', 'DOLocationID': '210', 'trip_distance': 1.3},
#  {'PULocationID': '66', 'DOLocationID': '67', 'trip_distance': 6.47},
#  {'PULocationID': '40', 'DOLocationID': '195', 'trip_distance': 1.15},
#  {'PULocationID': '112', 'DOLocationID': '80', 'trip_distance': 1.3},
#  {'PULocationID': '256', 'DOLocationID': '186', 'trip_distance': 4.75}]

# %%
train_dicts = df[categorical + numerical].to_dict(orient="records")

# %% [markdown]
# #### Train Logistic Regression model

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
dv.feature_names_[:10] # one hot encoding
# Out:
# ['DOLocationID=1',
#  'DOLocationID=10',
#  'DOLocationID=100',
#  'DOLocationID=101',
#  'DOLocationID=102',
#  'DOLocationID=106',
#  'DOLocationID=107',
#  'DOLocationID=108',
#  'DOLocationID=11',
#  'DOLocationID=111']

# %%
target = 'duration'
y_train = df[target].values

# %%
X_train
# Out:
# <62495x472 sparse matrix of type '<class 'numpy.float64'>'
# 	with 187485 stored elements in Compressed Sparse Row format>

# %%
y_train
# Out:
# array([ 1.2       ,  8.71666667, 16.2       , ..., 19.        ,
#        10.        , 34.        ])

# %%
lr = LinearRegression() 
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
X_train.shape,y_train.shape
# Out:
# ((62495, 472), (62495,))

# %%
ax = sns.distplot(y_pred,label="predicted")
ax = sns.distplot(y_train,label="true values")

# %%
mse(y_train,y_pred,squared=False)
# Out:
# 77.77314609577849
